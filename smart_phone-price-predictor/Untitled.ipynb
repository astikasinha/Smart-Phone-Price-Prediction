# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('smartphones.csv')

# %%
df.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price
# 0   8.0    256.0  Yellow  Yes       231.60
# 1   4.0    128.0    Blue  Yes       279.00
# 2   4.0    128.0    Blue  Yes       179.01
# 3   6.0    128.0    Gray  Yes       279.99
# 4  12.0    512.0   White  Yes       799.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1816 entries, 0 to 1815
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Smartphone   1816 non-null   object
#  1   Brand        1816 non-null   object
#  2   Model        1816 non-null   object
#  3   RAM          1333 non-null   float64
#  4   Storage      1791 non-null   float64
#  5   Color        1816 non-null   object
#  6   Free         1816 non-null   object
#  7   Final Price  1816 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 113.6+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Smartphone       0
# Brand            0
# Model            0
# RAM            483
# Storage         25
# Color            0
# Free             0
# Final Price      0
# dtype: int64

# %%
df_cleaned = df.dropna(subset=['RAM', 'Storage'])

# %%
df.isnull().sum()
# Out:
# Smartphone       0
# Brand            0
# Model            0
# RAM            483
# Storage         25
# Color            0
# Free             0
# Final Price      0
# dtype: int64

# %%
missing_values_summary = df_cleaned.isnull().sum()

# %%
df.isnull().sum()
# Out:
# Smartphone       0
# Brand            0
# Model            0
# RAM            483
# Storage         25
# Color            0
# Free             0
# Final Price      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Smartphone     0
# Brand          0
# Model          0
# RAM            0
# Storage        0
# Color          0
# Free           0
# Final Price    0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ...

# %%
df['Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
sns.barplot(x=df['Brand'],y=df['Price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ...

# %%
sns.barplot(x=df['Brand'],y=df['Final Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 sns.barplot(x=df['Brand'],y=df['Final Price'])
# ----> 2 plt.xticks(rotation='vertical')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df['Brand'],y=df['Final Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['RAM'],y=df['Final Price'])
# Out:
# <Axes: xlabel='RAM', ylabel='Final Price'>

# %%
df['Smartphone'].value_counts()
# Out:
# Smartphone
# Realme C55 8/256GB Sunshower Libre                                     1
# Samsung Galaxy S20 Plus 12/128GB 5G Cloud White Libre                  1
# Oppo Find X2 Lite 8/128GB 5G Blanco Libre                              1
# OnePlus 7T 8/128GB Azul Glaciar Libre                                  1
# OPPO Reno8 Pro 5G 8/256GB Negro Libre + Cable USB 3.1 Type-C           1
#                                                                       ..
# Xiaomi 13 8/256GB Blanco Libre                                         1
# Oppo A74 5G 6/128GB Plata Libre                                        1
# Cubot X70 12/256GB Space Black Libre                                   1
# Samsung Galaxy Z Fold4 12/256GB Beige Libre + Cargador de Pared 25W    1
# Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre                       1
# Name: count, Length: 1333, dtype: int64

# %%
df['128GB']=df['Smartphone'].apply(lambda x:1 if '128GB' in x else 0)

# %%
df.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price  128GB
# 0   8.0    256.0  Yellow  Yes       231.60      0
# 1   4.0    128.0    Blue  Yes       279.00      1
# 2   4.0    128.0    Blue  Yes       179.01      1
# 3   6.0    128.0    Gray  Yes       279.99      1
# 4  12.0    512.0   White  Yes       799.00      0

# %%
df.sample(5)
# Out:
#                                     Smartphone   Brand             Model  RAM  \
# 1497   Realme GT Neo 3 5G 8/256GB Blanco Libre  Realme          GT Neo 3  8.0
# 1191  Cubot King Kong Mini 2 3/32GB Rojo Libre   Cubot  King Kong Mini 2  3.0
# 702             POCO M5 4/128GB Amarillo Libre    POCO                M5  4.0
# 536    Xiaomi Redmi A2 2/32GB Azul Claro Libre  Xiaomi          Redmi A2  2.0
# 1275   Xiaomi Mi 9T 6/64GB Dual Sim Azul Libre  Xiaomi                9T  6.0
#
#       Storage   Color Free  Final Price  128GB
# 1497    256.0   White  Yes       549.78      0
# 1191     32.0     Red  Yes       148.24      0
# 702     128.0  Yellow  Yes       206.99      1
# 536      32.0    Blue  Yes        79.99      0
# 1275     64.0    Blue  Yes       428.00      0

# %%
sns.barplot(x=df['128GB'],y=df['Final Price'])
# Out:
# <Axes: xlabel='128GB', ylabel='Final Price'>

# %%
df['256GB']=df['Smartphone'].apply(lambda x:1 if '256GB' in x else 0)

# %%
sns.barplot(x=df['256GB'],y=df['Final Price'])
# Out:
# <Axes: xlabel='256GB', ylabel='Final Price'>

# %%
df['32GB']=df['Smartphone'].apply(lambda x:1 if '32GB' in x else 0)

# %%
df['64GB']=df['Smartphone'].apply(lambda x:1 if '64GB' in x else 0)

# %%
df['512GB']=df['Smartphone'].apply(lambda x:1 if '512GB' in x else 0)

# %%
sns.barplot(x=df['32GB'],y=df['Final Price'])
# Out:
# <Axes: xlabel='32GB', ylabel='Final Price'>

# %%
sns.barplot(x=df['64GB'],y=df['Final Price'])
# Out:
# <Axes: xlabel='64GB', ylabel='Final Price'>

# %%
sns.barplot(x=df['512GB'],y=df['Final Price'])
# Out:
# <Axes: xlabel='512GB', ylabel='Final Price'>

# %%
df['1TB']=df['Smartphone'].apply(lambda x:1 if '1TB' in x else 0)

# %%
sns.barplot(x=df['1TB'],y=df['Final Price'])
# Out:
# <Axes: xlabel='1TB', ylabel='Final Price'>

# %%
df['5G']=df['Smartphone'].apply(lambda x:1 if '5G' in x else 0)

# %%
sns.barplot(x=df['5G'],y=df['Final Price'])
# Out:
# <Axes: xlabel='5G', ylabel='Final Price'>

# %%
new=df['Smartphone'].str.split('/',n=1,expand=True)

# %%
df['ram']=new[0]
df['ROM']=new[1]

# %%
df.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price  128GB  256GB  32GB  64GB  512GB  \
# 0   8.0    256.0  Yellow  Yes       231.60      0      1     0     0      0
# 1   4.0    128.0    Blue  Yes       279.00      1      0     0     0      0
# 2   4.0    128.0    Blue  Yes       179.01      1      0     0     0      0
# 3   6.0    128.0    Gray  Yes       279.99      1      0     0     0      0
# 4  12.0    512.0   White  Yes       799.00      0      0     0     0      1
#
#    1TB  5G                      ram                       ROM
# ...

# %%
df.corr()['Final Price']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.corr()['Final Price']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1333 entries, 0 to 1815
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Smartphone   1333 non-null   object
#  1   Brand        1333 non-null   object
#  2   Model        1333 non-null   object
#  3   RAM          1333 non-null   float64
#  4   Storage      1333 non-null   float64
#  5   Color        1333 non-null   object
#  6   Free         1333 non-null   object
#  7   Final Price  1333 non-null   float64
#  8   128GB        1333 non-null   int64
#  9   256GB        1333 non-null   int64
#  10  32GB         1333 non-null   int64
#  11  64GB         1333 non-null   int64
#  12  512GB        1333 non-null   int64
#  13  1TB          1333 non-null   int64
#  14  5G           1333 non-null   int64
#  15  ram          1333 non-null   object
#  16  ROM          1333 non-null   object
# dtypes: float64(3), int64(7), object(7)
# memory usage: 187.5+ KB

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
price=df.copy()
price['Final Price']=price['Final Price'].astype(string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 price=df.copy()
# ----> 2 price['Final Price']=price['Final Price'].astype(string)
#
# NameError: name 'string' is not defined

# %%
df['Final Price'].astype('string')
# Out:
# 0        231.6
# 1        279.0
# 2       179.01
# 3       279.99
# 4        799.0
#          ...
# 1811    249.01
# 1812     200.0
# 1813     269.0
# 1814     211.0
# 1815     289.0
# Name: Final Price, Length: 1333, dtype: string

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df.corr()['Price']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df.corr()['Price']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
sns.barplot(x=df['ROM'],y=df['Final Price'])
# Out:
# <Axes: xlabel='ROM', ylabel='Final Price'>

# %%
sns.barplot(x=df['ROM'],y=df['Final Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['128GB'],y=df['Final Price'])
# Out:
# <Axes: xlabel='128GB', ylabel='Final Price'>

# %%
sns.barplot(x=df['Model'],y=df['Final Price'])
# Out:
# <Axes: xlabel='Model', ylabel='Final Price'>

# %%
sns.barplot(x=df['Brand'],y=df['Final Price'])
# Out:
# <Axes: xlabel='Brand', ylabel='Final Price'>

# %%
sns.barplot(x=df['RAM'],y=df['Final Price'])
# Out:
# <Axes: xlabel='RAM', ylabel='Final Price'>

# %%
res = ''.join(filter(lambda i: i.isdigit(), test_string))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 res = ''.join(filter(lambda i: i.isdigit(), test_string))
#
# NameError: name 'test_string' is not defined

# %%
res = ''.join(filter(lambda i: i.isdigit(), 'ROM'))

# %%
df['res']=''.join(filter(lambda i: i.isdigit(), 'ROM'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1333 entries, 0 to 1815
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Smartphone   1333 non-null   object
#  1   Brand        1333 non-null   object
#  2   Model        1333 non-null   object
#  3   RAM          1333 non-null   float64
#  4   Storage      1333 non-null   float64
#  5   Color        1333 non-null   object
#  6   Free         1333 non-null   object
#  7   Final Price  1333 non-null   float64
#  8   128GB        1333 non-null   int64
#  9   256GB        1333 non-null   int64
#  10  32GB         1333 non-null   int64
#  11  64GB         1333 non-null   int64
#  12  512GB        1333 non-null   int64
#  13  1TB          1333 non-null   int64
#  14  5G           1333 non-null   int64
#  15  ram          1333 non-null   object
#  16  ROM          1333 non-null   object
#  17  res          1333 non-null   object
# ...

# %%
df.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price  128GB  256GB  32GB  64GB  512GB  \
# 0   8.0    256.0  Yellow  Yes       231.60      0      1     0     0      0
# 1   4.0    128.0    Blue  Yes       279.00      1      0     0     0      0
# 2   4.0    128.0    Blue  Yes       179.01      1      0     0     0      0
# 3   6.0    128.0    Gray  Yes       279.99      1      0     0     0      0
# 4  12.0    512.0   White  Yes       799.00      0      0     0     0      1
#
# ...

# %%
df.drop(columns=['res','ram','ROM','128GB','256GB','32GB','64GB','512GB','1TB'],inplace=True)

# %%
df.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price  5G
# 0   8.0    256.0  Yellow  Yes       231.60   0
# 1   4.0    128.0    Blue  Yes       279.00   1
# 2   4.0    128.0    Blue  Yes       179.01   0
# 3   6.0    128.0    Gray  Yes       279.99   0
# 4  12.0    512.0   White  Yes       799.00   0

# %%
sns.barplot(x=df['Free'],y=df['Final Price'])
# Out:
# <Axes: xlabel='Free', ylabel='Final Price'>

# %%
df['Storage'].value_counts()
# Out:
# Storage
# 128.0    614
# 256.0    274
# 64.0     260
# 32.0     150
# 16.0      19
# 512.0     16
# Name: count, dtype: int64

# %%
df['5G'].value_counts()
# Out:
# 5G
# 0    867
# 1    466
# Name: count, dtype: int64

# %%
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 sns.heatmap(df.corr())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=tarin_test_split(X,y,test_size=0.15,random_state=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,y_train,y_test=tarin_test_split(X,y,test_size=0.15,random_state=2)
#
# NameError: name 'tarin_test_split' is not defined

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)
#
# NameError: name 'X' is not defined

# %%
sns.distplot(np.log(df['Final Price']))
# Out:
# C:\Users\astik\AppData\Local\Temp\ipykernel_24744\3897261032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Final Price']))
# <Axes: xlabel='Final Price', ylabel='Density'>

# %%
X=df.drop(columns=['Final Price'])
y=np.log(df['Final Price'])

# %%
X
# Out:
#                                             Smartphone     Brand  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  5G
# 0                C55   8.0    256.0  Yellow  Yes   0
# 1         Galaxy M23   4.0    128.0    Blue  Yes   1
# ...

# %%
y
# Out:
# 0       5.445012
# 1       5.631212
# 2       5.187442
# 3       5.634754
# 4       6.683361
#           ...
# 1811    5.517493
# 1812    5.298317
# 1813    5.594711
# 1814    5.351858
# 1815    5.666427
# Name: Final Price, Length: 1333, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined

# %%
x_train
# Out:
#                                              Smartphone    Brand  \
# 1180          Samsung Galaxy Z Flip4 8/128GB Rosa Libre  Samsung
# 730   Xiaomi PocoPhone X3 Pro 6/128GB Azul Helado Libre   Xiaomi
# 1384             Honor X7a 4/128GB Midnight Black Libre    Honor
# 1550  Samsung Galaxy M53 5G 6/128GB Marrón Libre Ver...  Samsung
# 1672               Xiaomi Redmi 10 4/128GB Blanco Libre   Xiaomi
# ...                                                 ...      ...
# 685                     Honor 70 5G 8/256GB Verde Libre    Honor
# 417                         POCO M5 4/128GB Verde Libre     POCO
# 726                 POCO F5 Pro 5G 8/256GB Blanco Libre     POCO
# 778               Samsung Galaxy A13 3/32GB Negro Libre  Samsung
# 1629             Ulefone Armor X5 Pro 4/64GB Rojo Libre  Ulefone
#
#                Model  RAM  Storage  Color Free  5G
# 1180  Galaxy Z Flip4  8.0    128.0   Pink  Yes   0
# 730               X3  6.0    128.0   Blue  Yes   0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression

# %%
df.head(1)
# Out:
#                            Smartphone   Brand Model  RAM  Storage   Color  \
# 0  Realme C55 8/256GB Sunshower Libre  Realme   C55  8.0    256.0  Yellow
#
#   Free  Final Price  5G
# 0  Yes        231.6   0

# %%
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,5,6])])
step2=LinearRegression()
pipe=Pipeline([('step1',step1),
              ('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\astik\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 6
#       3 pipe=Pipeline([('step1',step1),
#       4               ('step2',step2)])
#       5 pipe.fit(x_train,y_train)
# ----> 6 y_pred=pipe.predict(x_test)
#       7 print('R2 score',r2_score(y_test,y_pred))
#       8 print('MAE',mean_absolute_error(y_test,y_pred))
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:507, in Pipeline.predict(self, X, **predict_params)
#     505 Xt = X
#     506 for _, name, transform in self._iter(with_final=False):
# --> 507     Xt = transform.transform(Xt)
# ...

# %%
df['Smartphone'] = df['Smartphone'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df['Smartphone'] = df['Smartphone'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
df['5G'] = df['5G'].astype('string')

# %%
df['Storage'] = df['Storage'].astype('string')

# %%
df['RAM'] = df['RAM'].astype('string')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression

# %%
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,5,6])])
step2=LinearRegression()
pipe=Pipeline([('step1',step1),
              ('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\astik\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 6
#       3 pipe=Pipeline([('step1',step1),
#       4               ('step2',step2)])
#       5 pipe.fit(x_train,y_train)
# ----> 6 y_pred=pipe.predict(x_test)
#       7 print('R2 score',r2_score(y_test,y_pred))
#       8 print('MAE',mean_absolute_error(y_test,y_pred))
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:507, in Pipeline.predict(self, X, **predict_params)
#     505 Xt = X
#     506 for _, name, transform in self._iter(with_final=False):
# --> 507     Xt = transform.transform(Xt)
# ...

# %%
df['Smartphone'].isnull().sum()
df['Smartphone'].fillna('Unknown', inplace=True)

# %%
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,5,6])])
step2=LinearRegression()
pipe=Pipeline([('step1',step1),
              ('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\astik\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 6
#       3 pipe=Pipeline([('step1',step1),
#       4               ('step2',step2)])
#       5 pipe.fit(x_train,y_train)
# ----> 6 y_pred=pipe.predict(x_test)
#       7 print('R2 score',r2_score(y_test,y_pred))
#       8 print('MAE',mean_absolute_error(y_test,y_pred))
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:507, in Pipeline.predict(self, X, **predict_params)
#     505 Xt = X
#     506 for _, name, transform in self._iter(with_final=False):
# --> 507     Xt = transform.transform(Xt)
# ...
